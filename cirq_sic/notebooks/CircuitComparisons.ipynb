# %%
from cirq_sic import *

# %%
base_dir = "../experiments/runners/data"
print_all_gate_counts(base_dir)
# Out:
# data/sky_ground/11_2_25/d4/BasisMeasurementAfterWHPOVMOnBasisStatesTask/numerical_sic
# 	bqskit_server_4_optimized.json (0): [Rx: 59, CZPowGate: 33, Rz: 63, IdentityGate: 2. Total: 157]
# 	bqskit_server_4_optimized.json (1): [Rx: 68, CZPowGate: 39, Rz: 58, IdentityGate: 2. Total: 167]
# 	bqskit_server_4_optimized.json (2): [Rz: 61, Rx: 57, CZPowGate: 34, IdentityGate: 2. Total: 154]
# 	bqskit_server_4_optimized.json (3): [Rz: 62, Rx: 55, CZPowGate: 32, IdentityGate: 2. Total: 151]
# 	cirq_optimized.json (0): [PhasedXPowGate: 84, CZPowGate: 67, ZPowGate: 8, PhasedXZGate: 56. Total: 215]
# 	cirq_optimized.json (1): [PhasedXPowGate: 84, CZPowGate: 67, ZPowGate: 8, PhasedXZGate: 56. Total: 215]
# 	cirq_optimized.json (2): [PhasedXPowGate: 84, CZPowGate: 67, ZPowGate: 8, PhasedXZGate: 56. Total: 215]
# 	cirq_optimized.json (3): [PhasedXPowGate: 84, CZPowGate: 67, ZPowGate: 8, PhasedXZGate: 56. Total: 215]
# ...
